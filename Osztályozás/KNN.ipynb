# %%
import pandas as pd
import numpy as np
import researchpy as rp
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import os
ldir = os.chdir(r'C:\Users\Gergely\Documents\Datasets')

# %%
df = pd.read_csv('Cars.csv')
df.head()
# Out:
#    Acceleration  Cylinders  Displacement  Horsepower  Miles_per_Gallon  \
# 0          12.0          8         307.0       130.0              18.0
# 1          11.5          8         350.0       165.0              15.0
# 2          11.0          8         318.0       150.0              18.0
# 3          12.0          8         304.0       150.0              16.0
# 4          10.5          8         302.0       140.0              17.0
#
#                         Name Origin  Weight_in_lbs        Year
# 0  chevrolet chevelle malibu    USA           3504  1970-01-01
# 1          buick skylark 320    USA           3693  1970-01-01
# 2         plymouth satellite    USA           3436  1970-01-01
# 3              amc rebel sst    USA           3433  1970-01-01
# 4                ford torino    USA           3449  1970-01-01

# %%
df.dropna(inplace=True)

# %%
sns.pairplot(df)

# %%
#Feltételezések:
#Nincsenek hiányzó értékek
#Folytonos változók

from sklearn.neighbors import KNeighborsClassifier

#Nagyobb k érték = simább döntési határ (overfitting elkerülése)
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(np.array(df['Horsepower']).reshape(-1, 1), np.array(df['Origin']).reshape(-1, 1))
# Out:
# C:\Users\Gergely\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                      weights='uniform')

# %%
knn.predict([[200]])
# Out:
# array(['USA'], dtype=object)
