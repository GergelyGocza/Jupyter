# %%
import pandas as pd
import numpy as np
from vega_datasets import data
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import ipywidgets
import qgrid

# %%
df = data.cars()
df.head()
# Out:
#    Acceleration  Cylinders  Displacement  Horsepower  Miles_per_Gallon  \
# 0          12.0          8         307.0       130.0              18.0
# 1          11.5          8         350.0       165.0              15.0
# 2          11.0          8         318.0       150.0              18.0
# 3          12.0          8         304.0       150.0              16.0
# 4          10.5          8         302.0       140.0              17.0
#
#                         Name Origin  Weight_in_lbs       Year
# 0  chevrolet chevelle malibu    USA           3504 1970-01-01
# 1          buick skylark 320    USA           3693 1970-01-01
# 2         plymouth satellite    USA           3436 1970-01-01
# 3              amc rebel sst    USA           3433 1970-01-01
# 4                ford torino    USA           3449 1970-01-01

# %%
qgrid_widget = qgrid.show_grid(df, show_toolbar=True)
qgrid_widget
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…

# %%
df.head()
# Out:
#    Acceleration  Cylinders  Displacement  Horsepower  Miles_per_Gallon  \
# 0          12.0          8         307.0       130.0              18.0
# 1          11.5          8         350.0       165.0              15.0
# 2          11.0          8         318.0       150.0              18.0
# 3          12.0          8         304.0       150.0              16.0
# 4          10.5          8         302.0       140.0              17.0
#
#                         Name Origin  Weight_in_lbs       Year
# 0  chevrolet chevelle malibu    USA           3504 1970-01-01
# 1          buick skylark 320    USA           3693 1970-01-01
# 2         plymouth satellite    USA           3436 1970-01-01
# 3              amc rebel sst    USA           3433 1970-01-01
# 4                ford torino    USA           3449 1970-01-01

# %%
qgrid_widget.get_changed_df()
# Out:
#      Acceleration  Cylinders  Displacement  Horsepower  Miles_per_Gallon  \
# 0            12.0          8         307.0       130.0              18.0
# 1            11.5          8         350.0       165.0              15.0
# 2            11.0          8         318.0       150.0              18.0
# 3            12.0          8         304.0       150.0              16.0
# 4            10.5          8         302.0       140.0              17.0
# 5            10.0          8         429.0       198.0              15.0
# 6             9.0          8         454.0       220.0              14.0
# 7             8.5          8         440.0       215.0              14.0
# 8            10.0          8         455.0       225.0              14.0
# 9             8.5          8         390.0       190.0              15.0
# 10           17.5          4         133.0       115.0               NaN
# 11           11.5          8         350.0       165.0               NaN
# ...

# %%
df.head()
# Out:
#    Acceleration  Cylinders  Displacement  Horsepower  Miles_per_Gallon  \
# 0          12.0          8         307.0       130.0              18.0
# 1          11.5          8         350.0       165.0              15.0
# 2          11.0          8         318.0       150.0              18.0
# 3          12.0          8         304.0       150.0              16.0
# 4          10.5          8         302.0       140.0              17.0
#
#                         Name Origin  Weight_in_lbs       Year
# 0  chevrolet chevelle malibu    USA           3504 1970-01-01
# 1          buick skylark 320    USA           3693 1970-01-01
# 2         plymouth satellite    USA           3436 1970-01-01
# 3              amc rebel sst    USA           3433 1970-01-01
# 4                ford torino    USA           3449 1970-01-01

# %%
new_df = qgrid_widget.get_changed_df()
new_df.head()
# Out:
#    Acceleration  Cylinders  Displacement  Horsepower  Miles_per_Gallon  \
# 0          12.0          8         307.0       130.0              18.0
# 1          11.5          8         350.0       165.0              15.0
# 2          11.0          8         318.0       150.0              18.0
# 3          12.0          8         304.0       150.0              16.0
# 4          10.5          8         302.0       140.0              17.0
#
#                         Name Origin  Weight_in_lbs       Year
# 0  chevrolet chevelle malibu    USA           3504 1970-01-01
# 1          buick skylark 320    USA           3693 1970-01-01
# 2         plymouth satellite    USA           3436 1970-01-01
# 3              amc rebel sst    USA           3433 1970-01-01
# 4                ford torino    USA           3449 1970-01-01

# %%
sns.set(rc={'figure.figsize': (12, 7)})
@ipywidgets.interact
def plot(color=['steelblue', 'green'], y_=['Horsepower', 'Weight_in_lbs', 'Acceleration', 'Miles_per_Gallon']):
         (sns.barplot(data=df, x='Origin', y=y_, color=color).set_title('Average value by Origin'))
# Out:
# interactive(children=(Dropdown(description='color', options=('steelblue', 'green'), value='steelblue'), Dropdo…

# %%
df.groupby(by='Origin').mean().T
# Out:
# Origin                 Europe        Japan          USA
# Acceleration        16.821918    16.172152    14.942520
# Cylinders            4.150685     4.101266     6.283465
# Displacement       109.465753   102.708861   247.935039
# Horsepower          81.000000    79.835443   119.900000
# Miles_per_Gallon    27.891429    30.450633    20.083534
# Weight_in_lbs     2431.493151  2221.227848  3372.700787

# %%
sns.set(rc={'figure.figsize': (12, 7)})
@ipywidgets.interact
def plot(color_=['Origin', 'Cylinders'],
         y_=['Horsepower', 'Weight_in_lbs', 'Acceleration', 'Miles_per_Gallon'],
         x_=['Horsepower', 'Weight_in_lbs', 'Acceleration', 'Miles_per_Gallon']):
         (sns.relplot(data=df, x=x_, y=y_, kind='scatter', hue=color_, height=6, aspect=2))
# Out:
# interactive(children=(Dropdown(description='color_', options=('Origin', 'Cylinders'), value='Origin'), Dropdow…

# %%
def boxplotIpw(df, h_v):
    oszlopok = list(df.columns)
    oszlopok.insert(0, '')
    if (h_v == 'h'):
        @ipywidgets.interact
        def plot(x_=df.select_dtypes(include=['int16', 'int32', 'int64', 'float16', 'float32', 'float64']).columns, y_=oszlopok, palette_=['pastel', 'Set2', 'husl', 'vlag', 'Paired']):
            (sns.boxplot(x=x_, y=y_, data=df, whis=1.5, palette=palette_, orient=h_v))
    elif (h_v == 'v'):
        @ipywidgets.interact
        def plot(x_=oszlopok, y_=df.select_dtypes(include=['int16', 'int32', 'int64', 'float16', 'float32', 'float64']).columns, palette_=['pastel', 'Set2', 'husl', 'vlag', 'Paired']):
            (sns.boxplot(x=x_, y=y_, data=df, whis=1.5, palette=palette_, orient=h_v))

boxplotIpw(df, 'h')
# Out:
# interactive(children=(Dropdown(description='x_', options=('Acceleration', 'Cylinders', 'Displacement', 'Horsep…
